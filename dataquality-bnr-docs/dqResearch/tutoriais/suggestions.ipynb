# %% [markdown]
# # DQ Research module
#
# * Analyzer
# * Profile
# * __Suggestions__
#
#
# ### Constraint Suggestion
#
# Get useful Constraint Suggestions based on your data distribution.</br>

# %% [markdown]
# #### Setup environment

# %% [markdown]
# ##### import libraries

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql import SparkSession, Row, DataFrame

# %%
from dataquality_bnr.dqSupport import main as dqSup

# %% [markdown]
# ##### Set up a PySpark session

# %%
spark = SparkSession.builder\
        .appName("pdq_helloWorld")\
        .enableHiveSupport()\
        .config("spark.sql.catalogImplementation","hive")\
        .config("spark.jars", dqSup.getDeequJar_path())\
        .config("spark.jars.excludes", dqSup.getDeequJar_excludes())\
        .config("spark.executor.memory","12g")\
        .config("spark.executor.memoryOverhead","8g")\
        .config("spark.shuffle.service.enabled","true")\
        .config("spark.dynamicAllocation.enabled","true")\
        .config("spark.dynamicAllocation.initialExecutors","1")\
        .config("spark.dynamicAllocation.maxExecutors","32")\
        .config("spark.dynamicAllocation.minExecutors","1")\
        .config("spark.executor.cores","2")\
        .config("spark.driver.memory","12g")\
        .config("spark.driver.maxResultSize","8g")\
        .config("spark.network.timeout","8000")\
        .config("spark.hadoop.hive.metastore.client.socket.timeout","900")\
        .config("spark.sql.hive.convertMetastoreParquet","true")\
        .config("spark.sql.broadcastTimeout","36000")\
        .config("spark.ui.killEnabled","true")\
        .config('spark.yarn.queue','root.gapl_plataf_projetos_motores_decisao')\
        .getOrCreate()

# %% [markdown]
# ### Dataset
# We will be running the analyzers on a dataset sampled from th.thbpd38 table

# %%
sql_query = """
select
    i1c_renda_final,
    i1c_lim_pre_ap_preventivo,
    i1c_rating_riscos,
    i1d_idade,
    i1d_sexo,
    i1c_cli_possui_conta,
    i1c_soc_cd_segm_empr1,
    i1c_soc_cd_ramo_atvd1,
    dat_ref_carga
from th.thbpd381 where dat_ref_carga='2022-01-03'
"""
df_input = spark.sql(sql_query)

# %%
df_input.printSchema()
# Out:
# root
#  |-- i1c_renda_final: integer (nullable = true)
#  |-- i1c_lim_pre_ap_preventivo: integer (nullable = true)
#  |-- i1c_rating_riscos: integer (nullable = true)
#  |-- i1d_idade: integer (nullable = true)
#  |-- i1d_sexo: string (nullable = true)
#  |-- i1c_cli_possui_conta: string (nullable = true)
#  |-- i1c_soc_cd_segm_empr1: integer (nullable = true)
#  |-- i1c_soc_cd_ramo_atvd1: integer (nullable = true)
#  |-- dat_ref_carga: string (nullable = true)

# %% [markdown]
# ## Constraint Suggestions

# %% [markdown]
# *dqResearch.runConstraintSuggestion(spark, df)*
# * *spark*: SparkSession
# * *df*: Dataframe

# %%
from dataquality_bnr.dqResearch import main as dqResearch

# %%
suggestions_df = dqResearch.runConstraintSuggestion(spark, df_input)

# %% [markdown]
# ##### show results
#
# Get Dataframe inMemory then show it with *pandas.DataFrame*

# %%
suggestions_df.toPandas()
# Out:
#                                   code_for_constraint  \
# 0                            .isComplete("i1d_idade")
# 1                         .isNonNegative("i1d_idade")
# 2   .isContainedIn("i1c_lim_pre_ap_preventivo", ["...
# 3            .isComplete("i1c_lim_pre_ap_preventivo")
# 4   .isContainedIn("i1c_lim_pre_ap_preventivo", ["...
# 5         .isNonNegative("i1c_lim_pre_ap_preventivo")
# 6     .isContainedIn("dat_ref_carga", ["2022-01-03"])
# 7                        .isComplete("dat_ref_carga")
# 8   .isContainedIn("i1c_cli_possui_conta", ["1", "...
# 9                 .isComplete("i1c_cli_possui_conta")
# 10             .isNonNegative("i1c_cli_possui_conta")
# 11  .hasDataType("i1c_cli_possui_conta", Constrain...
# 12        .isContainedIn("i1d_sexo", ["M", "F", " "])
# 13                            .isComplete("i1d_sexo")
# 14  .isContainedIn("i1d_sexo", ["M", "F"], lambda ...
# 15            .isNonNegative("i1c_soc_cd_ramo_atvd1")
# 16  .isContainedIn("i1c_rating_riscos", ["0", "1",...
# 17                   .isComplete("i1c_rating_riscos")
# 18  .isContainedIn("i1c_rating_riscos", ["0", "1",...
# 19                .isNonNegative("i1c_rating_riscos")
# 20  .isContainedIn("i1c_soc_cd_segm_empr1", ["12",...
# 21  .isContainedIn("i1c_soc_cd_segm_empr1", [""], ...
# 22            .isNonNegative("i1c_soc_cd_segm_empr1")
# 23                     .isComplete("i1c_renda_final")
# 24                  .isNonNegative("i1c_renda_final")
#
#                   column_name  \
# 0                   i1d_idade
# 1                   i1d_idade
# 2   i1c_lim_pre_ap_preventivo
# 3   i1c_lim_pre_ap_preventivo
# 4   i1c_lim_pre_ap_preventivo
# 5   i1c_lim_pre_ap_preventivo
# 6               dat_ref_carga
# 7               dat_ref_carga
# 8        i1c_cli_possui_conta
# 9        i1c_cli_possui_conta
# 10       i1c_cli_possui_conta
# 11       i1c_cli_possui_conta
# 12                   i1d_sexo
# 13                   i1d_sexo
# 14                   i1d_sexo
# 15      i1c_soc_cd_ramo_atvd1
# 16          i1c_rating_riscos
# 17          i1c_rating_riscos
# 18          i1c_rating_riscos
# 19          i1c_rating_riscos
# 20      i1c_soc_cd_segm_empr1
# 21      i1c_soc_cd_segm_empr1
# 22      i1c_soc_cd_segm_empr1
# 23            i1c_renda_final
# 24            i1c_renda_final
#
#                                       constraint_name  \
# 0   CompletenessConstraint(Completeness(i1d_idade,...
# 1   ComplianceConstraint(Compliance('i1d_idade' ha...
# 2   ComplianceConstraint(Compliance('i1c_lim_pre_a...
# 3   CompletenessConstraint(Completeness(i1c_lim_pr...
# 4   ComplianceConstraint(Compliance('i1c_lim_pre_a...
# 5   ComplianceConstraint(Compliance('i1c_lim_pre_a...
# 6   ComplianceConstraint(Compliance('dat_ref_carga...
# 7   CompletenessConstraint(Completeness(dat_ref_ca...
# 8   ComplianceConstraint(Compliance('i1c_cli_possu...
# 9   CompletenessConstraint(Completeness(i1c_cli_po...
# 10  ComplianceConstraint(Compliance('i1c_cli_possu...
# 11  AnalysisBasedConstraint(DataType(i1c_cli_possu...
# 12  ComplianceConstraint(Compliance('i1d_sexo' has...
# 13  CompletenessConstraint(Completeness(i1d_sexo,N...
# 14  ComplianceConstraint(Compliance('i1d_sexo' has...
# 15  ComplianceConstraint(Compliance('i1c_soc_cd_ra...
# 16  ComplianceConstraint(Compliance('i1c_rating_ri...
# 17  CompletenessConstraint(Completeness(i1c_rating...
# 18  ComplianceConstraint(Compliance('i1c_rating_ri...
# 19  ComplianceConstraint(Compliance('i1c_rating_ri...
# 20  ComplianceConstraint(Compliance('i1c_soc_cd_se...
# 21  ComplianceConstraint(Compliance('i1c_soc_cd_se...
# 22  ComplianceConstraint(Compliance('i1c_soc_cd_se...
# 23  CompletenessConstraint(Completeness(i1c_renda_...
# 24  ComplianceConstraint(Compliance('i1c_renda_fin...
#
#                      current_value  \
# 0                Completeness: 1.0
# 1                     Minimum: 0.0
# 2                    Compliance: 1
# 3                Completeness: 1.0
# 4   Compliance: 0.9917453091629286
# 5                     Minimum: 0.0
# 6                    Compliance: 1
# 7                Completeness: 1.0
# 8                    Compliance: 1
# 9                Completeness: 1.0
# 10                    Minimum: 0.0
# 11              DataType: Integral
# 12                   Compliance: 1
# 13               Completeness: 1.0
# 14  Compliance: 0.9984185283445539
# 15                    Minimum: 0.0
# 16                   Compliance: 1
# 17               Completeness: 1.0
# 18  Compliance: 0.9342026500735311
# 19                    Minimum: 0.0
# 20                   Compliance: 1
# 21  Compliance: 0.9218206138179238
# 22                   Minimum: 11.0
# 23               Completeness: 1.0
# 24                    Minimum: 0.0
#
#                                           description  \
# 0                             'i1d_idade' is not null
# 1                  'i1d_idade' has no negative values
# 2   'i1c_lim_pre_ap_preventivo' has value range '0...
# 3             'i1c_lim_pre_ap_preventivo' is not null
# 4   'i1c_lim_pre_ap_preventivo' has value range '0...
# 5   'i1c_lim_pre_ap_preventivo' has no negative va...
# 6        'dat_ref_carga' has value range '2022-01-03'
# 7                         'dat_ref_carga' is not null
# 8     'i1c_cli_possui_conta' has value range '1', '0'
# 9                  'i1c_cli_possui_conta' is not null
# 10      'i1c_cli_possui_conta' has no negative values
# 11           'i1c_cli_possui_conta' has type Integral
# 12           'i1d_sexo' has value range 'M', 'F', ' '
# 13                             'i1d_sexo' is not null
# 14  'i1d_sexo' has value range 'M', 'F' for at lea...
# 15     'i1c_soc_cd_ramo_atvd1' has no negative values
# 16  'i1c_rating_riscos' has value range '0', '1', ...
# 17                    'i1c_rating_riscos' is not null
# 18  'i1c_rating_riscos' has value range '0', '1', ...
# 19         'i1c_rating_riscos' has no negative values
# 20  'i1c_soc_cd_segm_empr1' has value range '12', ...
# 21  'i1c_soc_cd_segm_empr1' has value range '' for...
# 22     'i1c_soc_cd_segm_empr1' has no negative values
# 23                      'i1c_renda_final' is not null
# 24           'i1c_renda_final' has no negative values
#
#                                      rule_description  \
# 0   If a column is complete in the sample, we sugg...
# 1   If we see only non-negative numbers in a colum...
# 2   If we see a categorical range for a column, we...
# 3   If a column is complete in the sample, we sugg...
# 4   If we see a categorical range for most values ...
# 5   If we see only non-negative numbers in a colum...
# 6   If we see a categorical range for a column, we...
# 7   If a column is complete in the sample, we sugg...
# 8   If we see a categorical range for a column, we...
# 9   If a column is complete in the sample, we sugg...
# 10  If we see only non-negative numbers in a colum...
# 11  If we detect a non-string type, we suggest a t...
# 12  If we see a categorical range for a column, we...
# 13  If a column is complete in the sample, we sugg...
# 14  If we see a categorical range for most values ...
# 15  If we see only non-negative numbers in a colum...
# 16  If we see a categorical range for a column, we...
# 17  If a column is complete in the sample, we sugg...
# 18  If we see a categorical range for most values ...
# 19  If we see only non-negative numbers in a colum...
# 20  If we see a categorical range for a column, we...
# 21  If we see a categorical range for most values ...
# 22  If we see only non-negative numbers in a colum...
# 23  If a column is complete in the sample, we sugg...
# 24  If we see only non-negative numbers in a colum...
#
#                         suggesting_rule
# 0              CompleteIfCompleteRule()
# 1              NonNegativeNumbersRule()
# 2                CategoricalRangeRule()
# 3              CompleteIfCompleteRule()
# 4   FractionalCategoricalRangeRule(0.9)
# 5              NonNegativeNumbersRule()
# 6                CategoricalRangeRule()
# 7              CompleteIfCompleteRule()
# 8                CategoricalRangeRule()
# 9              CompleteIfCompleteRule()
# 10             NonNegativeNumbersRule()
# 11                     RetainTypeRule()
# 12               CategoricalRangeRule()
# 13             CompleteIfCompleteRule()
# 14  FractionalCategoricalRangeRule(0.9)
# 15             NonNegativeNumbersRule()
# 16               CategoricalRangeRule()
# 17             CompleteIfCompleteRule()
# 18  FractionalCategoricalRangeRule(0.9)
# 19             NonNegativeNumbersRule()
# 20               CategoricalRangeRule()
# 21  FractionalCategoricalRangeRule(0.9)
# 22             NonNegativeNumbersRule()
# 23             CompleteIfCompleteRule()
# 24             NonNegativeNumbersRule()
